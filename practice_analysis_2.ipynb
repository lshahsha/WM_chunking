# %%
import pandas as pd

data_1 = pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s10\WMC_s10.csv")
df_1 = pd.DataFrame (data_1)

data_2= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s12\WMC_s12.csv")
df_2 = pd.DataFrame (data_2)

data_3= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s14\WMC_s14.csv")
df_3 = pd.DataFrame (data_3)

data_4= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s15\WMC_s15.csv")
df_4 = pd.DataFrame (data_4)

data_5= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s11\WMC_s11.csv")
df_5 = pd.DataFrame (data_5)

data_6= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s16\WMC_s16.csv")
df_6 = pd.DataFrame (data_6)

data_7= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s17\WMC_s17.csv")
df_7 = pd.DataFrame (data_7)

data_8= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s18\WMC_s18.csv")
df_8 = pd.DataFrame (data_8)

data_9= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s19\WMC_s19.csv")
df_9 = pd.DataFrame (data_9)

data_10= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s20\WMC_s20.csv")
df_10 = pd.DataFrame (data_10)

data_11= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s21\WMC_s21.csv")
df_11 = pd.DataFrame (data_11)

data_12= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s22\WMC_s22.csv")
df_12 = pd.DataFrame (data_12)

data_13= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s23\WMC_s23.csv")
df_13 = pd.DataFrame (data_13)

data_14= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s24\WMC_s24.csv")
df_14 = pd.DataFrame (data_14)

data_15= pd.read_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\s25\WMC_s25.csv")
df_15 = pd.DataFrame (data_15)

# %% [markdown]
# # Data cleaning

# %%
import numpy as np

arr0 = np.array(list(range(0,16)))
arr1 = np.array(list(range(0,24)))
arr2 = np.array(list(range(0,24)))
arr3 = np.array(list(range(0,24)))
arr4 = np.array(list(range(0,24)))
arr5 = np.array(list(range(0,24)))
arr6 = np.array(list(range(0,24)))
arr7 = np.array(list(range(0,24)))
arr8 = np.array(list(range(0,24)))

arr = np.concatenate((arr0, arr1,arr2 ,arr3 ,arr4, arr5, arr6, arr7, arr8))

df_1['Tn'] = arr
df_2['Tn'] = arr
df_3['Tn'] = arr
df_4['Tn'] = arr
df_5['Tn'] = arr
df_6['Tn'] = arr
df_7['Tn'] = arr
df_8['Tn'] = arr
df_9['Tn'] = arr
df_10['Tn'] = arr
df_11['Tn'] = arr
df_12['Tn'] = arr
df_13['Tn'] = arr
df_14['Tn'] = arr
df_15['Tn'] = arr

# %%
df_1 =df_1[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_2 =df_2[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_3 =df_3[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_4 =df_4[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_5 =df_5[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_6 =df_6[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_7 =df_7[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_8 =df_8[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_9 =df_9[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_10 =df_10[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_11 =df_11[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_12 =df_12[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_13 =df_13[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_14 =df_14[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]
df_15 =df_15[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir', 'response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur']]

# %%
response_times_1 = [[],[],[],[],[],[]]
for row in df_1["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_1[idx].append(0)
        else: 
            response_times_1[idx].append(float(val))

# %%
#P2
test_list = response_times_1[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_1[1] = P2

#P3
test_list = response_times_1[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_1[2] = P3

#P4
test_list = response_times_1[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_1[3] = P4

#P5
test_list = response_times_1[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_1[4] = P5

#P6
test_list = response_times_1[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_1[5] = P6

# %%
response_times_2 = [[],[],[],[],[],[]]
for row in df_2["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_2[idx].append(0)
        else: 
            response_times_2[idx].append(float(val))

# %%
#P2
test_list = response_times_2[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_2[1] = P2

#P3
test_list = response_times_2[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_2[2] = P3

#P4
test_list = response_times_2[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_2[3] = P4

#P5
test_list = response_times_2[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_2[4] = P5

#P6
test_list = response_times_2[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_2[5] = P6

# %%
response_times_3 = [[],[],[],[],[],[]]
for row in df_3["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_3[idx].append(0)
        else: 
            response_times_3[idx].append(float(val))

# %%
#P2
test_list = response_times_3[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_3[1] = P2

#P3
test_list = response_times_3[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_3[2] = P3

#P4
test_list = response_times_3[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_3[3] = P4

#P5
test_list = response_times_3[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_3[4] = P5

#P6
test_list = response_times_3[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_3[5] = P6

# %%
response_times_4 = [[],[],[],[],[],[]]
for row in df_4["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_4[idx].append(0)
        else: 
            response_times_4[idx].append(float(val))

# %%
#P2
test_list = response_times_4[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_4[1] = P2

#P3
test_list = response_times_4[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_4[2] = P3

#P4
test_list = response_times_4[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_4[3] = P4

#P5
test_list = response_times_4[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_4[4] = P5

#P6
test_list = response_times_4[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_4[5] = P6

# %%
response_times_5 = [[],[],[],[],[],[]]
for row in df_5["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_5[idx].append(0)
        else: 
            response_times_5[idx].append(float(val))

# %%
#P2
test_list = response_times_5[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_5[1] = P2

#P3
test_list = response_times_5[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_5[2] = P3

#P4
test_list = response_times_5[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_5[3] = P4

#P5
test_list = response_times_5[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_5[4] = P5

#P6
test_list = response_times_5[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_5[5] = P6

# %%
response_times_6 = [[],[],[],[],[],[]]
for row in df_6["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_6[idx].append(0)
        else: 
            response_times_6[idx].append(float(val))

# %%
#P2
test_list = response_times_6[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_6[1] = P2

#P3
test_list = response_times_6[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_6[2] = P3

#P4
test_list = response_times_6[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_6[3] = P4

#P5
test_list = response_times_6[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_6[4] = P5

#P6
test_list = response_times_6[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_6[5] = P6

# %%
response_times_7 = [[],[],[],[],[],[]]
for row in df_7["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_7[idx].append(0)
        else: 
            response_times_7[idx].append(float(val))

# %%
#P2
test_list = response_times_7[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_7[1] = P2

#P3
test_list = response_times_7[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_7[2] = P3

#P4
test_list = response_times_7[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_7[3] = P4

#P5
test_list = response_times_7[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_7[4] = P5

#P6
test_list = response_times_7[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_7[5] = P6

# %%
response_times_8 = [[],[],[],[],[],[]]
for row in df_8["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_8[idx].append(0)
        else: 
            response_times_8[idx].append(float(val))

# %%
#P2
test_list = response_times_8[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_8[1] = P2

#P3
test_list = response_times_8[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_8[2] = P3

#P4
test_list = response_times_8[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_8[3] = P4

#P5
test_list = response_times_8[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_8[4] = P5

#P6
test_list = response_times_8[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_8[5] = P6

# %%
response_times_9 = [[],[],[],[],[],[]]
for row in df_9["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_9[idx].append(0)
        else: 
            response_times_9[idx].append(float(val))

# %%
#P2
test_list = response_times_9[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_9[1] = P2

#P3
test_list = response_times_9[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_9[2] = P3

#P4
test_list = response_times_9[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_9[3] = P4

#P5
test_list = response_times_9[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_9[4] = P5

#P6
test_list = response_times_9[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_9[5] = P6

# %%
response_times_10 = [[],[],[],[],[],[]]
for row in df_10["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_10[idx].append(0)
        else: 
            response_times_10[idx].append(float(val))

# %%
#P2
test_list = response_times_10[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_10[1] = P2

#P3
test_list = response_times_10[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_10[2] = P3

#P4
test_list = response_times_10[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_10[3] = P4

#P5
test_list = response_times_10[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_10[4] = P5

#P6
test_list = response_times_10[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_10[5] = P6

# %%
response_times_11 = [[],[],[],[],[],[]]
for row in df_11["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_11[idx].append(0)
        else: 
            response_times_11[idx].append(float(val))

# %%
#P2
test_list = response_times_11[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_11[1] = P2

#P3
test_list = response_times_11[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_11[2] = P3

#P4
test_list = response_times_11[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_11[3] = P4

#P5
test_list = response_times_11[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_11[4] = P5

#P6
test_list = response_times_11[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_11[5] = P6

# %%
response_times_12 = [[],[],[],[],[],[]]
for row in df_12["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_12[idx].append(0)
        else: 
            response_times_12[idx].append(float(val))

# %%
#P2
test_list = response_times_12[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_12[1] = P2

#P3
test_list = response_times_12[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_12[2] = P3

#P4
test_list = response_times_12[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_12[3] = P4

#P5
test_list = response_times_12[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_12[4] = P5

#P6
test_list = response_times_12[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_12[5] = P6

# %%
response_times_13 = [[],[],[],[],[],[]]
for row in df_13["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_13[idx].append(0)
        else: 
            response_times_13[idx].append(float(val))

# %%
#P2
test_list = response_times_13[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_13[1] = P2

#P3
test_list = response_times_13[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_13[2] = P3

#P4
test_list = response_times_13[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_13[3] = P4

#P5
test_list = response_times_13[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_13[4] = P5

#P6
test_list = response_times_13[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_13[5] = P6

# %%
response_times_14 = [[],[],[],[],[],[]]
for row in df_14["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_14[idx].append(0)
        else: 
            response_times_14[idx].append(float(val))

# %%
#P2
test_list = response_times_14[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_14[1] = P2

#P3
test_list = response_times_14[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_14[2] = P3

#P4
test_list = response_times_14[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_14[3] = P4

#P5
test_list = response_times_14[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_14[4] = P5

#P6
test_list = response_times_14[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_14[5] = P6

# %%
response_times_15 = [[],[],[],[],[],[]]
for row in df_15["response_time"]:
    row = row[1:-1]
    trial_s = row.split(", ")
    for idx, val in enumerate(trial_s):
        if val == '':
            response_times_15[idx].append(0)
        else: 
            response_times_15[idx].append(float(val))

# %%
#P2
test_list = response_times_15[1]
app_list = [0]
N = 1
P2 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P2.extend(app_list)
	P2.append(ele)
response_times_15[1] = P2

#P3
test_list = response_times_15[2]
app_list = [0]
N = 1
P3 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P3.extend(app_list)
	P3.append(ele)
response_times_15[2] = P3

#P4
test_list = response_times_15[3]
app_list = [0]
N = 1
P4 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P4.extend(app_list)
	P4.append(ele)
response_times_15[3] = P4

#P5
test_list = response_times_15[4]
app_list = [0]
N = 1
P5 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P5.extend(app_list)
	P5.append(ele)
response_times_15[4] = P5

#P6
test_list = response_times_15[5]
app_list = [0]
N = 1
P6 = []
for idx, ele in enumerate(test_list):
	if idx % N == 0:
		P6.extend(app_list)
	P6.append(ele)
response_times_15[5] = P6

# %%
df_1['P1'] = response_times_1[0]
df_1['P2'] = response_times_1[1]
df_1['P3'] = response_times_1[2]
df_1['P4'] = response_times_1[3]
df_1['P5'] = response_times_1[4]
df_1['P6'] = response_times_1[5]

df_2['P1'] = response_times_2[0]
df_2['P2'] = response_times_2[1]
df_2['P3'] = response_times_2[2]
df_2['P4'] = response_times_2[3]
df_2['P5'] = response_times_2[4]
df_2['P6'] = response_times_2[5]

df_3['P1'] = response_times_3[0]
df_3['P2'] = response_times_3[1]
df_3['P3'] = response_times_3[2]
df_3['P4'] = response_times_3[3]
df_3['P5'] = response_times_3[4]
df_3['P6'] = response_times_3[5]

df_4['P1'] = response_times_4[0]
df_4['P2'] = response_times_4[1]
df_4['P3'] = response_times_4[2]
df_4['P4'] = response_times_4[3]
df_4['P5'] = response_times_4[4]
df_4['P6'] = response_times_4[5]

df_5['P1'] = response_times_5[0]
df_5['P2'] = response_times_5[1]
df_5['P3'] = response_times_5[2]
df_5['P4'] = response_times_5[3]
df_5['P5'] = response_times_5[4]
df_5['P6'] = response_times_5[5]

df_6['P1'] = response_times_6[0]
df_6['P2'] = response_times_6[1]
df_6['P3'] = response_times_6[2]
df_6['P4'] = response_times_6[3]
df_6['P5'] = response_times_6[4]
df_6['P6'] = response_times_6[5]

df_7['P1'] = response_times_7[0]
df_7['P2'] = response_times_7[1]
df_7['P3'] = response_times_7[2]
df_7['P4'] = response_times_7[3]
df_7['P5'] = response_times_7[4]
df_7['P6'] = response_times_7[5]

df_8['P1'] = response_times_8[0]
df_8['P2'] = response_times_8[1]
df_8['P3'] = response_times_8[2]
df_8['P4'] = response_times_8[3]
df_8['P5'] = response_times_8[4]
df_8['P6'] = response_times_8[5]

df_9['P1'] = response_times_9[0]
df_9['P2'] = response_times_9[1]
df_9['P3'] = response_times_9[2]
df_9['P4'] = response_times_9[3]
df_9['P5'] = response_times_9[4]
df_9['P6'] = response_times_9[5]

df_10['P1'] = response_times_10[0]
df_10['P2'] = response_times_10[1]
df_10['P3'] = response_times_10[2]
df_10['P4'] = response_times_10[3]
df_10['P5'] = response_times_10[4]
df_10['P6'] = response_times_10[5]

df_11['P1'] = response_times_11[0]
df_11['P2'] = response_times_11[1]
df_11['P3'] = response_times_11[2]
df_11['P4'] = response_times_11[3]
df_11['P5'] = response_times_11[4]
df_11['P6'] = response_times_11[5]

df_12['P1'] = response_times_12[0]
df_12['P2'] = response_times_12[1]
df_12['P3'] = response_times_12[2]
df_12['P4'] = response_times_12[3]
df_12['P5'] = response_times_12[4]
df_12['P6'] = response_times_12[5]

df_13['P1'] = response_times_13[0]
df_13['P2'] = response_times_13[1]
df_13['P3'] = response_times_13[2]
df_13['P4'] = response_times_13[3]
df_13['P5'] = response_times_13[4]
df_13['P6'] = response_times_13[5]

df_14['P1'] = response_times_14[0]
df_14['P2'] = response_times_14[1]
df_14['P3'] = response_times_14[2]
df_14['P4'] = response_times_14[3]
df_14['P5'] = response_times_14[4]
df_14['P6'] = response_times_14[5]

df_15['P1'] = response_times_15[0]
df_15['P2'] = response_times_15[1]
df_15['P3'] = response_times_15[2]
df_15['P4'] = response_times_15[3]
df_15['P5'] = response_times_15[4]
df_15['P6'] = response_times_15[5]

# %%
df_1['IPI_1'] = df_1['P2'] - df_1['P1']
df_1['IPI_2'] = df_1['P3'] - df_1['P2']
df_1['IPI_3'] = df_1['P4'] - df_1['P3']
df_1['IPI_4'] = df_1['P5'] - df_1['P4']
df_1['IPI_5'] = df_1['P6'] - df_1['P5']

df_2['IPI_1'] = df_2['P2'] - df_2['P1']
df_2['IPI_2'] = df_2['P3'] - df_2['P2']
df_2['IPI_3'] = df_2['P4'] - df_2['P3']
df_2['IPI_4'] = df_2['P5'] - df_2['P4']
df_2['IPI_5'] = df_2['P6'] - df_2['P5']

df_3['IPI_1'] = df_3['P2'] - df_3['P1']
df_3['IPI_2'] = df_3['P3'] - df_3['P2']
df_3['IPI_3'] = df_3['P4'] - df_3['P3']
df_3['IPI_4'] = df_3['P5'] - df_3['P4']
df_3['IPI_5'] = df_3['P6'] - df_3['P5']

df_4['IPI_1'] = df_4['P2'] - df_4['P1']
df_4['IPI_2'] = df_4['P3'] - df_4['P2']
df_4['IPI_3'] = df_4['P4'] - df_4['P3']
df_4['IPI_4'] = df_4['P5'] - df_4['P4']
df_4['IPI_5'] = df_4['P6'] - df_4['P5']

df_5['IPI_1'] = df_5['P2'] - df_5['P1']
df_5['IPI_2'] = df_5['P3'] - df_5['P2']
df_5['IPI_3'] = df_5['P4'] - df_5['P3']
df_5['IPI_4'] = df_5['P5'] - df_5['P4']
df_5['IPI_5'] = df_5['P6'] - df_5['P5']

df_6['IPI_1'] = df_6['P2'] - df_6['P1']
df_6['IPI_2'] = df_6['P3'] - df_6['P2']
df_6['IPI_3'] = df_6['P4'] - df_6['P3']
df_6['IPI_4'] = df_6['P5'] - df_6['P4']
df_6['IPI_5'] = df_6['P6'] - df_6['P5']

df_7['IPI_1'] = df_7['P2'] - df_7['P1']
df_7['IPI_2'] = df_7['P3'] - df_7['P2']
df_7['IPI_3'] = df_7['P4'] - df_7['P3']
df_7['IPI_4'] = df_7['P5'] - df_7['P4']
df_7['IPI_5'] = df_7['P6'] - df_7['P5']

df_8['IPI_1'] = df_8['P2'] - df_8['P1']
df_8['IPI_2'] = df_8['P3'] - df_8['P2']
df_8['IPI_3'] = df_8['P4'] - df_8['P3']
df_8['IPI_4'] = df_8['P5'] - df_8['P4']
df_8['IPI_5'] = df_8['P6'] - df_8['P5']

df_9['IPI_1'] = df_9['P2'] - df_9['P1']
df_9['IPI_2'] = df_9['P3'] - df_9['P2']
df_9['IPI_3'] = df_9['P4'] - df_9['P3']
df_9['IPI_4'] = df_9['P5'] - df_9['P4']
df_9['IPI_5'] = df_9['P6'] - df_9['P5']

df_10['IPI_1'] = df_10['P2'] - df_10['P1']
df_10['IPI_2'] = df_10['P3'] - df_10['P2']
df_10['IPI_3'] = df_10['P4'] - df_10['P3']
df_10['IPI_4'] = df_10['P5'] - df_10['P4']
df_10['IPI_5'] = df_10['P6'] - df_10['P5']

df_11['IPI_1'] = df_11['P2'] - df_11['P1']
df_11['IPI_2'] = df_11['P3'] - df_11['P2']
df_11['IPI_3'] = df_11['P4'] - df_11['P3']
df_11['IPI_4'] = df_11['P5'] - df_11['P4']
df_11['IPI_5'] = df_11['P6'] - df_11['P5']

df_12['IPI_1'] = df_12['P2'] - df_12['P1']
df_12['IPI_2'] = df_12['P3'] - df_12['P2']
df_12['IPI_3'] = df_12['P4'] - df_12['P3']
df_12['IPI_4'] = df_12['P5'] - df_12['P4']
df_12['IPI_5'] = df_12['P6'] - df_12['P5']

df_13['IPI_1'] = df_13['P2'] - df_13['P1']
df_13['IPI_2'] = df_13['P3'] - df_13['P2']
df_13['IPI_3'] = df_13['P4'] - df_13['P3']
df_13['IPI_4'] = df_13['P5'] - df_13['P4']
df_13['IPI_5'] = df_13['P6'] - df_13['P5']

df_14['IPI_1'] = df_14['P2'] - df_14['P1']
df_14['IPI_2'] = df_14['P3'] - df_14['P2']
df_14['IPI_3'] = df_14['P4'] - df_14['P3']
df_14['IPI_4'] = df_14['P5'] - df_14['P4']
df_14['IPI_5'] = df_14['P6'] - df_14['P5']

df_15['IPI_1'] = df_15['P2'] - df_15['P1']
df_15['IPI_2'] = df_15['P3'] - df_15['P2']
df_15['IPI_3'] = df_15['P4'] - df_15['P3']
df_15['IPI_4'] = df_15['P5'] - df_15['P4']
df_15['IPI_5'] = df_15['P6'] - df_15['P5']

# %%
IPI_0 = []
for idx in df_1.index[3:]:
    IPI0 = df_1['P1'][idx] - (df_1['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -50:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_1['P1'][1] - 6.5
df_1['IPI_0'] = IPI_0
df_1 = df_1[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_2.index[3:]:
    IPI0 = df_2['P1'][idx] - (df_2['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -50:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_2['P1'][1] - 6.5
df_2['IPI_0'] = IPI_0
df_2 = df_2[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_3.index[3:]:
    IPI0 = df_3['P1'][idx] - (df_3['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -50:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_3['P1'][1] - 6.5
df_3['IPI_0'] = IPI_0
df_3 = df_3[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_4.index[3:]:
    IPI0 = df_4['P1'][idx] - (df_4['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -50:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_4['P1'][1] - 6.5
df_4['IPI_0'] = IPI_0
df_4 = df_4[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_5.index[3:]:
    IPI0 = df_5['P1'][idx] - (df_5['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -50:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_5['P1'][1] - 6.5
df_5['IPI_0'] = IPI_0
df_5 = df_5[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_6.index[3:]:
    IPI0 = df_6['P1'][idx] - (df_6['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_6['P1'][1] - 6.5
df_6['IPI_0'] = IPI_0
df_6 = df_6[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_7.index[3:]:
    IPI0 = df_7['P1'][idx] - (df_7['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_7['P1'][1] - 6.5
df_7['IPI_0'] = IPI_0
df_7 = df_7[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_8.index[3:]:
    IPI0 = df_8['P1'][idx] - (df_8['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_8['P1'][1] - 6.5
df_8['IPI_0'] = IPI_0
df_8 = df_8[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_9.index[3:]:
    IPI0 = df_9['P1'][idx] - (df_9['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_9['P1'][1] - 6.5
df_9['IPI_0'] = IPI_0
df_9 = df_9[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_10.index[3:]:
    IPI0 = df_10['P1'][idx] - (df_10['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_10['P1'][1] - 6.5
df_10['IPI_0'] = IPI_0
df_10 = df_10[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_11.index[3:]:
    IPI0 = df_11['P1'][idx] - (df_11['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_11['P1'][1] - 6.5
df_11['IPI_0'] = IPI_0
df_11 = df_11[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_12.index[3:]:
    IPI0 = df_12['P1'][idx] - (df_12['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_12['P1'][1] - 6.5
df_12['IPI_0'] = IPI_0
df_12 = df_12[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_13.index[3:]:
    IPI0 = df_13['P1'][idx] - (df_13['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_13['P1'][1] - 6.5
df_13['IPI_0'] = IPI_0
df_13 = df_13[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_14.index[3:]:
    IPI0 = df_14['P1'][idx] - (df_14['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_14['P1'][1] - 6.5
df_14['IPI_0'] = IPI_0
df_14 = df_14[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
IPI_0 = []
for idx in df_15.index[3:]:
    IPI0 = df_15['P1'][idx] - (df_15['P6'][idx-2] + 6 + 0.5)
    if IPI0 == -6.5:
        IPI0 = 0
    elif IPI0 < -20:
        IPI0 = "NaN"
    IPI_0.append(IPI0)

# %%
IPI_0 = [0,0,0] + IPI_0
IPI_0[1] = df_15['P1'][1] - 6.5
df_15['IPI_0'] = IPI_0
df_15 = df_15[['Tn', 'MT', 'chunk', 'display_trial_feedback', 'feedback_dur', 'feedback_type', 'hand', 'is_error', 'item_dur', 'iti_dur', 'number_correct', 'phase', 'phase_type', 'points', 'recall_dir','response', 'response_time', 'run_number', 'seq_length', 'seq_str', 'trial_dur', 'P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'IPI_0', 'IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
df_1s = df_1.iloc[16: , :]
df_2s = df_2.iloc[16: , :]
df_3s = df_3.iloc[16: , :]
df_4s = df_4.iloc[16: , :]
df_5s = df_5.iloc[16: , :]
df_6s = df_6.iloc[16: , :]
df_7s = df_7.iloc[16: , :]
df_8s = df_8.iloc[16: , :]
df_9s = df_9.iloc[16: , :]
df_10s = df_10.iloc[16: , :]
df_11s = df_11.iloc[16: , :]
df_12s = df_12.iloc[16: , :]
df_13s = df_13.iloc[16: , :]
df_14s = df_14.iloc[16: , :]
df_15s = df_15.iloc[16: , :]

frames = [df_1s, df_2s, df_3s, df_4s, df_5s, df_6s, df_7s, df_8s, df_9s, df_10s, df_11s, df_12s, df_13s, df_14s, df_15s]
df = pd.concat(frames)
df.to_csv(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\Merged_data.csv")

# %% [markdown]
# # Plotting Data
#     #1)Organize data for what you are plotting
#     #2)plotting IPI vs. Time: IPI (x-axis), Time (Y-axis)

# %%
Chunk2_BW = df.loc[(df['chunk'] == 2) & (df['recall_dir'] == 0) & (df['IPI_1'] != 0), ['IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]
Chunk2_FW = df.loc[(df['chunk'] == 2) & (df['recall_dir'] == 1) & (df['IPI_1'] != 0), ['IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]
Chunk3_BW = df.loc[(df['chunk'] == 3) & (df['recall_dir'] == 0) & (df['IPI_1'] != 0), ['IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]
Chunk3_FW = df.loc[(df['chunk'] == 3) & (df['recall_dir'] == 1) & (df['IPI_1'] != 0), ['IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']]

# %%
import matplotlib.pyplot as plt

A = Chunk2_FW.mean()
A.plot(kind='line')
#plt.legend(["C2-FW"])

B = Chunk2_BW.mean()
B.plot(kind='line')
#plt.legend(["C2-BW"])

C = Chunk3_FW.mean()
C.plot(kind='line')
#plt.legend(["C3-FW"])

D = Chunk3_BW.mean()
D.plot(kind='line')
#plt.legend(["C3-BW"])

plt.legend(["C2-FW", "C2-BW", "C3-FW", "C3-BW"])
plt.xlabel(r'IPIs', fontsize=20)
plt.ylabel(r'Time(s)', fontsize=20)
plt.savefig(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\Merged_plot1.pdf", dpi=300)

# %%
import matplotlib.pyplot as plt

x_axis = ['IPI_1', 'IPI_2', 'IPI_3', 'IPI_4', 'IPI_5']
line1 = plt.plot(x_axis, Chunk2_FW.mean(),'bo-',label='C2-FW')
line2 = plt.plot(x_axis, Chunk2_BW.mean(),'mo-',label='C2-FW')
line3 = plt.plot(x_axis, Chunk3_FW.mean(),'go-',label='C2-FW')
line4 = plt.plot(x_axis, Chunk3_BW.mean(),'ro-',label='C2-FW')

#plt.fill_between(x_axis, Chunk2_FW.mean() + Chunk2_FW.std(), Chunk2_FW.mean() - Chunk2_FW.std(), color='b', alpha=0.2)
#plt.fill_between(x_axis, Chunk2_BW.mean() + Chunk2_BW.std(), Chunk2_BW.mean() - Chunk2_BW.std(), color='m', alpha=0.2)
#plt.fill_between(x_axis, Chunk3_FW.mean() + Chunk3_FW.std(), Chunk3_FW.mean() - Chunk3_FW.std(), color='g', alpha=0.2)
#plt.fill_between(x_axis, Chunk3_BW.mean() + Chunk3_BW.std(), Chunk3_BW.mean() - Chunk3_BW.std(), color='r', alpha=0.2)

plt.legend(["C2-FW", "C2-BW", "C3-FW", "C3-BW"])
plt.xlabel(r'IPIs', fontsize=20)
plt.ylabel(r'Time(s)', fontsize=20)
plt.savefig(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\Merged_plot2.pdf", dpi=300)

# %%
RT_C2_FW = df.loc[(df['chunk'] == 2) & (df['recall_dir'] == 0) & (df['IPI_0'] != 0) & (df['Tn'] != 1), ['IPI_0']]
RT_C2_BW = df.loc[(df['chunk'] == 2) & (df['recall_dir'] == 1) & (df['IPI_0'] != 0) & (df['Tn'] != 1), ['IPI_0']]
RT_C3_FW = df.loc[(df['chunk'] == 3) & (df['recall_dir'] == 0) & (df['IPI_0'] != 0) & (df['Tn'] != 1), ['IPI_0']]
RT_C3_BW = df.loc[(df['chunk'] == 3) & (df['recall_dir'] == 1) & (df['IPI_0'] != 0) & (df['Tn'] != 1), ['IPI_0']]

# %%
RT1 =[]
for x in RT_C2_FW['IPI_0']:
    if x > 0:
        RT1.append(x)

# %%
RT2 =[]
for x in RT_C2_BW['IPI_0']:
    if x > 0:
        RT2.append(x)

# %%
RT3 =[]
for x in RT_C3_FW['IPI_0']:
    if x > 0:
        RT3.append(x)

# %%
RT4 =[]
for x in RT_C3_BW['IPI_0']:
    if x > 0:
        RT4.append(x)

# %%
import numpy as np

RT1 = np.array(RT1)
RT2 = np.array(RT2)
RT3 = np.array(RT3)
RT4 = np.array(RT4)

# %%
Forward = [RT1.mean(), RT3.mean()]
Backward = [RT2.mean(), RT4.mean()]
index = ['C2', 'C3']
df = pd.DataFrame({'Forward': Forward, 'Backward': Backward}, index=index)
df.plot.bar(rot=0)
plt.xlabel(r'Chunking Strategy', fontsize=20)
plt.ylabel(r'Reaction Time(s)', fontsize=20)
plt.savefig(r"C:\Users\khash\OneDrive\Documents\GitHub\WM_chunking\data\behavioural\raw\RT_plot.pdf", dpi=300)

# %% [markdown]
# # Next step:
# * write a function that creates a dataframe with data from all the subjects and save the new dataframe
# * create the figures with averaged data across subjects
